# %%
#Define a function for multiple two numbers
def Mutl(a,b):
    c = a * b
    return(c)
    print('This is not printed ')
result = Mutl(12,2)
print(result)
# Out:
# 24

# %%
#Function Example
def type_of_album(artist,album,year_release):
    print(artist,album,year_release)
    if year_release > 1980:
        return 'Modern'
    else:
        return 'Oldie'
x = type_of_album('Michael Jackson','Thriller',1980)
print(x)
# Out:
# Michael Jackson Thriller 1980
# Oldie

# %%
#Print the list using for loop
def PrintList(the_list):
    for element in the_list:
        print(element)

# %%
PrintList(['1',1,'the man','abc'])
# Out:
# 1
# 1
# the man
# abc

# %%
#Python program to count words in a string using Dictionary
def freq(string):
    #step 1: A list variable is declared and initialized to an empty list.
    words =[]
    #step 2: Break the string into list of words
    words = string.split()
    #step 3: Declare a dictionary
    Dict = {}
    #step 4: Use for loop to iterate words and values to the dictionary
    for key in words:
        Dict[key] = words.count(key)
    #step 5: Print the dictionary
    print(f'The frequency of words is:{Dict}')
#step 6 :Call the function and pass string in it
freq('Mary has a little lamb Little Lamb, little lamb Mary had a little lamb. Its fleece' \
'Everywhere that Mary went the Lamb was sure to go')
# Out:
# The frequency of words is:{'Mary': 3, 'has': 1, 'a': 2, 'little': 3, 'lamb': 2, 'Little': 1, 'Lamb,': 1, 'had': 1, 'lamb.': 1, 'Its': 1, 'fleeceEverywhere': 1, 'that': 1, 'went': 1, 'the': 1, 'Lamb': 1, 'was': 1, 'sure': 1, 'to': 1, 'go': 1}

# %%
#Example for setting param with default value

def isGoodRating(rating=4):
    if rating < 7:
        print(f"This album sucks it's rating is {rating}")
    else:
        print(f"This album is good it's rating is {rating}")

# %%
isGoodRating()
isGoodRating(10)
# Out:
# This album sucks it's rating is 4
# This album is good it's rating is 10
