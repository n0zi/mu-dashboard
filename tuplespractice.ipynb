# %%
#Create your first tuple 
tuple1 = ('Disco',10,1.2)
tuple1
# Out:
# ('Disco', 10, 1.2)

# %%
#Print the type of the tuple you created 

type(tuple1)
# Out:
# tuple

# %%
#Print the type of value on each index
print(tuple1[0])
print(tuple1[1])
print(tuple1[2])
# Out:
# Disco
# 10
# 1.2

# %%
#Use negative index to get the value of the last element
tuple1[-1]
# Out:
# 1.2

# %%
#Use negative index to get the value of the second last element
tuple1[-2]
# Out:
# 10

# %%
#Use negative index to  get the value of the third last element 
tuple1[-3]
# Out:
# 'Disco'

# %%
# Concatenate two tuples
tuple2 =tuple1 + ('hard rock', 10)
tuple2
# Out:
# ('Disco', 10, 1.2, 'hard rock', 10)

# %%
tuple2[3:5]
# Out:
# ('hard rock', 10)

# %%
tuple2[0:3]
# Out:
# ('Disco', 10, 1.2)

# %%
#Slice from index 0 to index 2
tuple2[0:3]
# Out:
# ('Disco', 10, 1.2)

# %%
#Slice from index 3 to index 4
tuple2[3:5]
# Out:
# ('hard rock', 10)

# %%
#Get the length of tuple
len(tuple2)
# Out:
# 5

# %%
#A sample tuple 
Ratings = (0,9,6,5,10,8,9,6,2)

# %%
#Sort the tuple
RatingsSorted = sorted(Ratings)
RatingsSorted
# Out:
# [0, 2, 5, 6, 6, 8, 9, 9, 10]

# %%
#Create a nest tuple 
NestedT = (1,2,('pop','rock'),(3,4),('disco',(1,2)))

# %%
#Print element on each index

print(f'Element 0 of Tuple: {NestedT[0]}')
print(f'Element 1 of Tuple: {NestedT[1]}')
print(f'Element 2 of Tuple: {NestedT[2]}')
print(f'Element 3 of Tuple: {NestedT[3]}')
print(f'Element 4 of Tuple: {NestedT[4]}')
# Out:
# Element 0 of Tuple: 1
# Element 1 of Tuple: 2
# Element 2 of Tuple: ('pop', 'rock')
# Element 3 of Tuple: (3, 4)
# Element 4 of Tuple: ('disco', (1, 2))

# %%
#Print the first element in the second nested tuples 

NestedT[2][1][0]
# Out:
# 'r'

# %%
#Print the second element in the second nested tuples
NestedT[2][1][1]
# Out:
# 'o'

# %%
#Print the first element in the second nested tuples
NestedT[4][1][0]
# Out:
# 1

# %%
#Print the second element in the second nested tuples
NestedT[4][1][1]
# Out:
# 2

# %%
#Sample tuple 
genres_tuple  = ("pop", "rock", "soul", "hard rock", "soft rock", \
                "R&B", "progressive rock", "disco") 
genres_tuple
# Out:
# ('pop',
#  'rock',
#  'soul',
#  'hard rock',
#  'soft rock',
#  'R&B',
#  'progressive rock',
#  'disco')

# %%
len(genres_tuple)
# Out:
# 8

# %%
genres_tuple[3]
# Out:
# 'hard rock'

# %%
genres_tuple[3:6]
# Out:
# ('hard rock', 'soft rock', 'R&B')

# %%
genres_tuple[0:2]
# Out:
# ('pop', 'rock')

# %%
genres_tuple.index('disco')
# Out:
# 7

# %%
C_Tuple = (-5,1,-3)
C_Tuplesorted = sorted(C_Tuple)
C_Tuplesorted
# Out:
# [-5, -3, 1]
